# %% [markdown]
#                                                          Inheritance

# %% [markdown]
#                                                     Inheritance Questions

# %%
# 1. Bank Management System Create a Bank class with: • balance variable • deposit() • withdraw() • check_balance()
#  Create a User class that inherits Bank and displays the user's name. Perform deposit, withdrawal, and balance check. 
class Bank:
    def __init__(self, balance):
        self.balance = balance
    def deposit(self,amount):
        self.balance+=amount
        print("Your Account Has been credited with Amount Rs.",amount)
    def withdraw(self,amount):
        self.balance-=amount
        print("Your Account Has been debited with Amount Rs.",amount)
    def check_balance(self):
        print("Your Account Balance is Rs.",self.balance)
class user(Bank):
    def __init__(self,name, balance):
        self.name = name
        super().__init__(balance)
a=user('Naresh',10000)
print(a.name)
a.deposit(1000)
a.withdraw(500)
a.check_balance()
# Out:
# Naresh
# Your Account Has been credited with Amount Rs. 1000
# Your Account Has been debited with Amount Rs. 500
# Your Account Balance is Rs. 10500

# %%
# 2. Employee Salary System Create an Employee class with: • emp_name  • salary • display_details()
#  Create a Manager class that inherits Employee and adds a bonus(). Display the total salary. 
class Employee:
    def __init__(self,emp_name,salary):
        self.emp_name=emp_name
        self.salary=salary
    def display_details(self):
        return {"Name of the Employee ":self.emp_name,
         "Salary of the Employee:":self.salary
        }
class Manager(Employee):
    def __init__(self, emp_name, salary):
        super().__init__(emp_name, salary)
    def bonus(self,bonus_percent):
        self.salary=self.salary*bonus_percent+self.salary
        print("Your Total Salary After Adding Bonus :",self.salary)
a=Manager("naresh",1000)
print(a.display_details())
a.bonus(0.15)
# Out:
# {'Name of the Employee ': 'naresh', 'Salary of the Employee:': 1000}
# Your Total Salary After Adding Bonus : 1150.0

# %%
# 3. Student Result System Create a Student class with: • Name  • marks • display_marks()
#  Create a Result class that inherits Student and calculates whether the student has passed or failed. 
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def display_marks(self):
        print({'name':self.name,
               'marks':self.marks})
class Results(Student):
    def __init__(self, name, marks):
        super().__init__(name, marks)
    def calc(self):
        if self.marks>=45:
            print("Passed")
        else:
            print("Failed")
a=Results('naresh',50)
a.display_marks()
a.calc()
b=Results('naresh',34)
b.calc()
# Out:
# {'name': 'naresh', 'marks': 50}
# Passed
# Failed

# %%
# 4. Food Ordering System Using Multilevel Inheritance 
# Class 1: Restaurant • Create a method menu(item) that returns the price of the selected food item. 
#  Class 2: FoodCourt (inherits Restaurant) Create the following methods: • display_menu() – Display the available food items. 
#  • order() – Accept the food item from the user and allow multiple orders.  • 
# billing() – Display the total bill and add a packing charge of ₹20. 
#  Class 3: Customer (inherits FoodCourt) • Create an object of the Customer class. 
#  • Call the order() method.  
class Restaurent:
    def menu(self,item):
        if item=='pizza':
            return 250
        elif item=='chicken_biryani':
            return 450
        elif item=='mutton_biryani':
            return 4850
        else:
            return 0
class Foodcourt(Restaurent):
    def __init__(self):
        self.total=0
    def display_menu(self):
        print("Pizza - 250")
        print("Chicken Biryani - 450")
        print("Mutton Biryani - 4850")
    def order(self):
        while True:
            item=input("enter your item ")
            price=self.menu(item)
            if price==0:
                print("Item Not Available")
            else:
                self.total+=price
                print("Added",item,price)
            choice=input(("Do u want to order more (yes/no): "))
            if choice=='no':
                break
    def billing(self):
        print("Food Total:",self.total)
        print("Packing Charges: 20")
        self.total+=20
        print('Total Bill:',self.total)
class Customer(Foodcourt):
    def __init__(self):
        super().__init__()
naresh=Customer()
naresh.display_menu()
naresh.order()
naresh.billing()
# Out:
# Pizza - 250
# Chicken Biryani - 450
# Mutton Biryani - 4850
# Added pizza 250
# Food Total: 250
# Packing Charges: 20
# Total Bill: 270

# %%
# 5. Movie Ticket Booking System Using Multilevel Inheritance Class 1: Movie • Create a method ticket(movie) that returns the ticket price. 
#  Class 2: Booking (inherits Movie) Create the following methods: • movies() – Display the available movies.  
# • selection() – Allow the user to book multiple tickets.  • billing() – Display the total amount and add a booking charge of ₹30. 
#  Class 3: Customer (inherits Booking) • Create an object and call the selection() method.  
class movie:
    def ticket(self,movie):
        if movie=='peddi':
            return 250
        elif movie=='paradise':
            return  200
        elif movie=='kalki':
            return 500
        elif movie=='raaka':
            return 1600
        else:
            return 0
class booking(movie):
    def __init__(self):
        self.total=0
    def display_details(self):
        print("peddi-250\n paradise 200\n kalki 500\n rakaa 1600")
    def selection(self):
        while True:
            movie=input("enter the movie name to book")
            price=self.ticket(movie)
            if price==0:
                print("Movie Not Available")
            else:
                self.total+=price
                print("Ticket Booking Succesfull for",movie,price)
            choice=input("Do you want to book tickets for more movies (yes/no)")
            if choice=='no':
                break
    def billing(self):
        print("Total Price :",self.total)
        print("Booking charges Rs.30")
        print("Final Charges :",self.total+30)
class Customer(booking):
    def __init__(self):
        super().__init__()
n=Customer()
n.display_details()
n.selection()
n.billing()
# Out:
# peddi-250
#  paradise 200
#  kalki 500
#  rakaa 1600
# Ticket Booking Succesfull for paradise 200
# Total Price : 200
# Booking charges Rs.30
# Final Charges : 230

# %%
# 6. Online Course Enrollment System Using Multilevel Inheritance Class 1: Course • Create a method fee(course) that returns the course fee.  
# Class 2: Academy (inherits Course) Create the following methods: • courses() – Display available courses. 
#  • enroll() – Allow the user to enroll in multiple courses.  • billing() – Display the total fee and add a registration fee of ₹100. 
#  Class 3: Student (inherits Academy) • Create an object and call the enroll() method.  
class course:
    def fee(self,course):
        if course=='da':
            return 4500
        elif course=='ai':
            return 35000
        elif course=='ai/ml':
            return 45000
        else:
            return 0
class academy(course):
    def __init__(self):
        self.total=0
    def courses(self):
        print('da-4500')
        print('ai-35000')
        print('ai/ml-45000')
    def enroll(self):
        while True:
            cour=input("Enter the course you want to register")
            price=self.fee(cour)
            if price==0:
                print("Course not avaialable")
            else:
                self.total+=price
                print("You Have Successfully Registered for the",cour,'of Rs.',price)
            choice=input("Do you want to register more courses (yes/no)")
            if choice=='no':
                break
    def billing(self):
            print("Total Fee :",self.total)
            print("registration fee of ₹100.")
            print("Final Charges :",self.total+100)
class student(academy):
    def __init__(self):
        super().__init__()
n=student()
n.courses()
n.enroll()
n.billing()
# Out:
# da-4500
# ai-35000
# ai/ml-45000
# You Have Successfully Registered for the da of Rs. 4500
# You Have Successfully Registered for the ai of Rs. 35000
# Total Fee : 39500
# registration fee of ₹100.
# Final Charges : 39600

# %%
# 7. Cab Booking System Using Hierarchical Inheritance Class 1: Cab • Create methods to calculate the fare for Bike, Auto, and Car rides. 
#  Class 2: Uber (inherits Cab) • Create the methods menu(), booking(), and billing().  
# • Add 10% GST and apply a 15% discount if the bill is above ₹1000. 
#  Class 3: Ola (inherits Cab) • Create the methods menu(), booking(), and billing(). 
#  • Add 12% GST and apply a 20% discount if the bill is above ₹1500.  Driver Code •
#  Ask the user to choose Uber or Ola and call the booking() method
class cab:
    def fare(self,book):
        if book=='bike':
            return 10
        elif book=='auto':
            return 15
        elif book=='car':
            return  30
class uber(cab):
    def __init__(self):
        self.price=0
    def menu(self):
        print("1.Bike - ₹10/km\n2. Auto - ₹15/km \n3. car - ₹20/km")
    def booking(self):
        book=input("enter the cab you want to book")
        distance=int(input("enter the distance you want to travel"))
        self.price=self.fare(book)*distance
    def billing(self):
        print("Total Fare:",self.price)
        gst=0.10*self.price
        self.price+=gst
        print("Added Gst of 10%")
        # print("Final Charge after Gst Added:",self.price+gst)
        if self.price>1000:
            self.price=self.price*0.15-self.price
            print("Your Final Fare is Rs.",self.price)
        else:
            print("Your Final Fare is Rs.",self.price)
class ola(cab):
    def __init__(self):
        self.price=0
    def menu(self):
        print("1.Bike - ₹10/km\n2. Auto - ₹15/km \n3. car - ₹20/km")
    def booking(self):
        book=input("enter the cab you want to book")
        distance=int(input("enter the distance you want to travel"))
        self.price=self.fare(book)*distance
    def billing(self):
        print("Total Fare:",self.price)
        gst=0.12*self.price
        self.price+=gst
        print("Added Gst of 12%")
        if self.price>1000:
            self.price=self.price*0.20-self.price
            print("Your Final Fare is Rs.",self.price)
        else:
            print("Your Final Fare is Rs.",self.price)
# p=input("enter your choice")

n=ola()
n.menu()
n.booking()
n.billing()
p=uber()
p.menu()
p.booking()
p.billing()
# Out:
# 1.Bike - ₹10/km
# 2. Auto - ₹15/km
# 3. car - ₹20/km
# Total Fare: 300
# Added Gst of 12%
# Your Final Fare is Rs. 336.0
# 1.Bike - ₹10/km
# 2. Auto - ₹15/km
# 3. car - ₹20/km
# Total Fare: 300
# Added Gst of 10%
# Your Final Fare is Rs. 330.0

# %%
# 8. Grocery Shopping System Using Hierarchical Inheritance Class 1: Grocery • Create methods to return the price of Rice, Sugar, and Oil.  
# Class 2: Dmart (inherits Grocery) • Create the methods items(), shopping(), and billing().  • Add 5% GST and 
# apply a 10% discount if the bill is above ₹2000.  Class 3: Reliance Smart (inherits Grocery) • Create the methods items(), shopping(), and billing(). 
# • Add 5% GST and apply a 15% discount if the bill is above ₹2500.  Driver Code • Ask the user to choose the supermarket and call the shopping() method. 
class grocery:
    def menu(self,item):
        if item=='rice':
            return 45
        elif item=='sugar':
            return 60
        elif item=='oil':
            return 130
class dmart(grocery):
    def __init__(self):
        super().__init__()
        self.total=0
    def items(self):
        print("1.Rice-45/kg\n2.sugar-60/kg\n3.oil-130/l")
    def shopping(self):
        while True:
            item=input("enter the item you wanna buy : ")
            quantity=int(input(("enter the quantity you want to but(kgs/litres)")))
            price=self.menu(item)*quantity
            self.total+=price
            print("added",item,price)
            if self.total==0:
                print("item not available")
            choice=input("Do you want purchase more items (yes/no)")
            if choice=='no':
                break
    def billing(self):
        print("Your Billing Details")
        print("--------------------")
        print("Base Fare Rs.",self.total)
        gst=self.total*0.05
        self.total+=gst
        print(f"Gst Rs.{gst}:",self.total)
        if self.total>2000:
            print('applied disscount of 10%')
            self.total=self.total-self.total*0.10
        print("--------------------")
        print("Total Amount    :",self.total)
class reliance_smart(grocery):
    def __init__(self):
        super().__init__()
        self.total=0
    def items(self):
        print("1.Rice-45/kg\n2.sugar-60/kg\n3.oil-130/l")
    def shopping(self):
        while True:
            item=input("enter the item you wanna buy : ")
            quantity=int(input(("enter the quantity you want to but(kgs/litres)")))
            price=self.menu(item)*quantity
            self.total+=price
            print("added",item,price)
            if self.total==0:
                print("item not available")
            choice=input("Do you want purchase more items (yes/no)")
            if choice=='no':
                break
    def billing(self):
        print("Your Billing Details")
        print("--------------------")
        print("Base Fare :",self.total)
        gst=self.total*0.05
        self.total+=gst
        print(f"Gst {gst}:",self.total)
        if self.total>2500:
            print('applied disscount of 15%')
            self.total=self.total-self.total*0.15
        print("--------------------")
        print("Total Amount    :",self.total)
n=dmart()
n.items()
n.shopping()
n.billing()
print()
n=reliance_smart()
n.items()
n.shopping()
n.billing()
# Out:
# 1.Rice-45/kg
# 2.sugar-60/kg
# 3.oil-130/l
# added sugar 1200
# added oil 2600
# Your Billing Details
# --------------------
# Base Fare Rs. 3800
# Gst Rs.190.0: 3990.0
# applied disscount of 10%
# --------------------
# Total Amount    : 3591.0
#
# 1.Rice-45/kg
# 2.sugar-60/kg
# 3.oil-130/l
# added sugar 1200
# added oil 2600
# Your Billing Details
# --------------------
# Base Fare : 3800
# Gst 190.0: 3990.0
# applied disscount of 15%
# --------------------
# Total Amount    : 3391.5

# %%
# 9. Bus Ticket Booking System Using Hierarchical Inheritance Class 1: Bus • Create methods to return the fare for Sleeper, Semi-Sleeper,
#  and AC buses.  Class 2: RedBus (inherits Bus) • Create the methods routes(), booking(), and billing().  
# • Add 10% GST and a reservation charge of ₹30.  Class 3: AbhiBus (inherits Bus) • Create the methods routes(), booking(), and billing(). 
# • Add 10% GST and a reservation charge of ₹20.  Driver Code • Ask the user to choose the platform and call the booking() method. 
class bus:
    def fare(self,choice):
        if choice=='sleeper':
            return 350
        elif choice=='semi-slepeer':
            return 300
        elif choice=='ac':
            return 500
class redbus(bus):
    def __init__(self):
        super().__init__()
        self.total=0
    def routes(self):
        print("Welcome To Redbus....!")
        print("Available Routes:")
        print("1. Hyderabad -> Bangalore")
        print("2. Hyderabad -> Chennai")
        print("3. Hyderabad -> Mumbai")
        print("4. Bangalore -> Chennai")
    def booking(self):
        route=input("enter the route")
        seat_no=input("select your seat numbers ").split()
        choice=input("enter your coach type")
        price=self.fare(choice)
        self.total+=price
        print("Bokking Successfull...!")
        print("route ",route)
        print("Your seat Number ",seat_no)
        print("preferred type",choice)
    def billing(self):
        print("Bus Booking Details")
        print("-------------------------")
        print("Base Fare       : ",self.total)
        gst=self.total*0.10
        self.total+=gst
        print("GST",gst,":",self.total)
        self.total+=30
        print("Reservation Fee RS.30:",self.total)
        print("-------------------------")
        print("Total Amount    :",self.total)
class abhibus(bus):
    def __init__(self):
        super().__init__()
        self.total=0
    def routes(self):
        print("Welcome To Abhibus....!")
        print("Available Routes:")
        print("1. Hyderabad -> Bangalore")
        print("2. Hyderabad -> Chennai")
        print("3. Hyderabad -> Mumbai")
        print("4. Bangalore -> Chennai")
    def booking(self):
        route=input("enter the route")
        seat_no=input("select your seat numbers ").split()
        choice=input("enter your coach type")
        price=self.fare(choice)
        self.total+=price
        print("Bokking Successfull...!")
        print("route ",route)
        print("Your seat Number ",seat_no)
        print("preferred type",choice)
    def billing(self):
        print("Bus Booking Details")
        print("-------------------------")
        print("Base Fare       : ",self.total)
        gst=self.total*0.10
        self.total+=gst
        print("GST",gst,":",self.total)
        self.total+=20
        print("Reservation Fee RS.20:",self.total)
        print("-------------------------")
        print("Total Amount    :",self.total)
# n=redbus()
# n.routes()
# n.booking()
# n.billing()
# print()
# n=abhibus()
# n.routes()
# n.booking()
# n.billing()
choice=input("choose platfrom (redbus/abhibus)")
if choice=='redbus':
    u=redbus()
elif choice=='abhibus':
    u=abhibus()
u.routes()
u.booking()
u.billing()
# Out:
# Welcome To Redbus....!
# Available Routes:
# 1. Hyderabad -> Bangalore
# 2. Hyderabad -> Chennai
# 3. Hyderabad -> Mumbai
# 4. Bangalore -> Chennai
# Bokking Successfull...!
# route  Hyderabad -> Chennai
# Your seat Number  ['12']
# prefereed type ac
# Bus Booking Details
# -------------------------
# Base Fare       :  500
# GST 50.0 : 550.0
# Reservation Fee RS.30: 580.0
# -------------------------
# Total Amount    : 580.0

# %%
# 10. ATM System Using Multiple Inheritance Class 1: SBI • Create the methods deposit(amount) and check_balance().  
# Class 2: UnionBank • Create the methods withdraw(amount) and mini_statement().  Class 3: ATM (inherits SBI and UnionBank) • 
# Create the methods menu() and transaction().  • Allow the user to perform banking operations.  Driver Code • Create an object of the ATM class.
#  • Call the transaction() method.
class sbi:
    def __init__(self,balance):
        self.balance=balance
        self.trans=[]
       
    def deposit(self,amount):
        if amount>0:
            self.balance+=amount
            print("Your Acc is credited with Rs.",amount)
        else:
            print("Deposit A Valid Amount")
    def check_balance(self):
        print("Your Current Acc Balance is ",self.balance)
class unionbank:
    def withdraw(self,amount):
        if amount<=self.balance:
            self.balance-=amount
            self.trans.append("Withdraw "+str(amount))
            print("Your Acc is debited with Rs.",amount)
        else:
            if amount>self.balance:
                print("Insufficient Funds")
            else:
                print("Enter A valid amount")
    def mini_statement(self):
        print("Mini Statement")
        for i in self.trans:
            print(i)
        print("Balance:", self.balance)
class atm(sbi,unionbank):
    def __init__(self, balance):
        super().__init__(balance)
    def menu(self):
        print("----- ATM MENU -----")
        print("1. Withdraw")
        print("2. Mini Statement")
        print("3. Check Balance")
        print("4. Deposit")
        print("5. Exit")
    def transaction(self):
        self.menu()
        while True:
            choice=int(input("enter your choice"))
            if choice==1:
                amount=int(input("enter your amount"))
                self.withdraw(amount)
            elif choice==2:
                self.mini_statement()
            elif choice==3:
                self.check_balance()
            elif choice==4:
                amount=int(input("enter your amount"))
                self.deposit(amount)
            elif choice==5:
                print("Thank You...!")
                break
    
a=atm(10000)
a.transaction()
# Out:
# ----- ATM MENU -----
# 1. Withdraw
# 2. Mini Statement
# 3. Check Balance
# 4. Deposit
# 5. Exit
# Your Acc is debited with Rs. 10
# Mini Statement
# Withdraw 10
# Balance: 9990
# Your Current Acc Balance is  9990
# Your Acc is credited with Rs. 10800
# Your Current Acc Balance is  20790
# Your Acc is debited with Rs. 1000
# Mini Statement
# Withdraw 10
# Withdraw 1000
# Balance: 19790
# Thank You...!
# Invalid

# %%
# 11. Paytm Application Using Multiple Inheritance Write a Python program to implement a Paytm Application using multiple inheritance.
#  Class 1: MobileRecharge • Create the methods recharge_plans() and mobile_rech arge().  
# Class 2: BusTicketBooking • Create the methods display_buses() and book_ticket(). Class 3: ElectricityBills 
# • Create the methods bill_details() and pay_bill().  Class 4: Paytm (inherits MobileRecharge, BusTicketBooking, and ElectricityBills) 
# Create the following methods: • menu() – Display the available services. 
# • services() – Allow the user to choose and use any service (Mobile Recharge, Bus Ticket Booking, or Electricity Bill Payment).  
class mobilerecharge:
    def recharge_plans(self):
        print("----- RECHARGE PLANS -----")
        print("1. ₹199 - 28 Days - 1GB/day")
        print("2. ₹299 - 28 Days - 1.5GB/day")
        print("3. ₹399 - 56 Days - 2GB/day")
    def mobile_recharge(self):
        self.recharge_plans()
        mobile = input("Enter mobile number: ")
        plan = int(input("Enter plan number: "))
        if plan == 1:
            print(f"Recharge of ₹199 successful for {mobile}")
        elif plan == 2:
            print(f"Recharge of ₹299 successful for {mobile}")
        elif plan == 3:
            print(f"Recharge of ₹399 successful for {mobile}")
        else:
            print("Invalid plan")
class busticketbooking:
    def display_buses(self):
        print("----- AVAILABLE BUSES -----")
        print("1. Orange Travels - Hyderabad to Bangalore")
        print("2. TSRTC - Hyderabad to Vijayawada")
        print("3. APSRTC - Hyderabad to Chennai")
    def book_ticket(self):
        self.display_buses()
        name = input("Enter passenger name: ")
        bus = int(input("Enter bus number: "))
        seats = int(input("Enter number of seats: "))
        if bus == 1:
            print("Orange Travels selected")
        elif bus == 2:
            print("TSRTC selected")
        elif bus == 3:
            print("APSRTC selected")
        else:
            print("Invalid bus")
        print("Passenger:", name)
        print("Seats:", seats)
        print("Ticket booked successfully...!")
class electricitybills:
    def bill_details(self):
        self.amount1=1200
        print("----- ELECTRICITY BILL -----")
        print("Consumer Number: 123456")
        print("Units Consumed: 150")
        print("Bill Amount: ₹1200")
    def pay_bill(self):
        self.bill_details()
        amount = int(input("Enter bill amount to pay: "))
        if amount ==self.amount1:
            print("Bill paid successfully")
            print("Amount paid: ₹", amount)
        else:
            print("Enter a valid amount")
class paytm(mobilerecharge,busticketbooking,electricitybills):
    def menu(self):
        print("----- PAYTM MENU -----")
        print("1. Mobile Recharge")
        print("2. Bus Ticket Booking")
        print("3. Electricity Bill Payment")
        print("4. Exit")
    def services(self):
        while True:
            choice=int(input("enter your choice "))
            if choice==1:
                self.mobile_recharge()
            elif choice==2:
                self.book_ticket()
            elif choice==3:
                self.pay_bill()
            else:
                print("Thank You...!")
                break
p=paytm()
p.menu()
p.services()
# Out:
# ----- PAYTM MENU -----
# 1. Mobile Recharge
# 2. Bus Ticket Booking
# 3. Electricity Bill Payment
# 4. Exit
# ----- RECHARGE PLANS -----
# 1. ₹199 - 28 Days - 1GB/day
# 2. ₹299 - 28 Days - 1.5GB/day
# 3. ₹399 - 56 Days - 2GB/day
# Recharge of ₹399 successful for 9948830350
# ----- AVAILABLE BUSES -----
# 1. Orange Travels - Hyderabad to Bangalore
# 2. TSRTC - Hyderabad to Vijayawada
# 3. APSRTC - Hyderabad to Chennai
# Orange Travels selected
# Passenger: Naresh
# Seats: 2
# Ticket booked successfully...!
# ----- ELECTRICITY BILL -----
# Consumer Number: 123456
# Units Consumed: 150
# Bill Amount: ₹1200
# Bill paid successfully
# Amount paid: ₹ 1200
# Thank You...!

# %%
class a:
    x='hi! naresh'
    y=2
    def __init__(self,c,d):
        self.c=c
        self.d=d
class b(a):
    z=3
    def __init__(self,e):
        self.e=e
        # a.__init__(self,10,20)
        super().__init__(20,30)
n=b(4)
print(n.e)
print(n.z)
print("class a class variables")
print(n.x)
print(n.y)
print("class a instance variables")
print(n.c)
print(n.d)
# Out:
# 4
# 3
# class a class variables
# hi! naresh
# 2
# class a instance variables
# 20
# 30

# %% [markdown]
#                                                            Super()

# %%
class A:
    c1 = "hey"
    c2 = 123
    def __init__(self, x, y):
        self.x = x
        self.y = y
class B(A):
    c3 = True
    def __init__(self, z, x, y):
        self.z = z
        # A.__init__(self,x, y)
        super().__init__(x, y)
b = B(10, 20, 30)
print(b.c1)
print(b.c2)
print(b.c3)
print("z :",b.z)
print("x :",b.x)
print("y :",b.y)
class A:
    def __init__(self, x):
        self.x = x
class B(A):
    def __init__(self, x , y):
        self.y = y
        # A.__init__(self, x)
        super().__init__(x)
class C(B):
    def __init__(self, x, y , z):
        self.z = z
        # B.__init__(self, x, y)
        super().__init__(x, y)
c = C(10, 20 , 30)
print("x: ",c.x)
print("y :",c.y)
print("z :" ,c.z)
# Out:
# hey
# 123
# True
# z : 10
# x : 20
# y : 30
# x:  10
# y : 20
# z : 30

# %%
class employee:
    def __init__(self,emp_id,name):
        self.emp_id=emp_id
        self.name=name

# %%
# class A:
#     def __init__(self):
#         print("A Constructor!!")
#
# class B(A):
#     def __init__(self):
#         print("B Constructor!!")
#         super().__init__()
# class C(B):
#     def __init__(self):
#         print("C Constructor!!")
#         super().__init__()
# c = C()
# print(C.mro())
# print(B.mro())
# print(A.mro())


# class A:
#     def __init__(self):
#         print("A Constructor!!")
#         super().__init__()
# class B:
#     def __init__(self):
#         print("B Constructor!!")
# class C(A, B):
#     def __init__(self):
#         print("C Constructor!!")
#         super().__init__()
# c = C()
# print(A.mro())
# print(B.mro())
# print(C.mro())
# print(C.__mro__)


class A:
    def __init__(self):
        print("A Constructor!!")

class B(A):
    def __init__(self):
        print("B Constructor!!")
        super().__init__()
class C(A):
    def __init__(self):
        print("C Constructor!!")
        super().__init__()
# c = C()
# b = B()

# class A:
#     def __init__(self):
#         print("A Constructor!!")
# class B(A):
#     def __init__(self):
#         print("B Constructor!!")
#         super().__init__()
# class C(A):
#     def __init__(self):
#         print("C Constructor!!")
#         super().__init__()
# class D(B, C):
#     def __init__(self):
#         print("D Constructor!!")
#         super().__init__()

# d = D()
# print(D.mro())
# y = (x.__name__ for x in D.mro())
# for i in y:
#     print(i)


class A:
    def __init__(self):
        # print("A Constructor!!")
        pass
    def m1(self):
        print("M1 - A")
    @classmethod
    def m2(cls):
        print("class method in A")
class B(A):
    def __init__(self):
        # print("B Constructor!!")
        super().__init__()
    def m1(self):
            print("M1 - B")
            super().m1()
    @classmethod
    def m2(cls):
        print("class method in B")
        super().m2()
class C(B):
    def __init__(self):
        # print("C Constructor!!")
        super().__init__()
    def m1(self):
        print("M1 - C")
        super().m1()
    @classmethod
    def m2(cls):
        print("class method in C")
        super().m2()
c = C()
# c.m1()
c.m2()
# Out:
# class method in C
# class method in B
# class method in A
